# %% [markdown]
# <a href="https://colab.research.google.com/github/nmorado/training/blob/master/Colab_5_Building_a_Recurrent_Neural_Network_in_TensorFlow_2_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Step 1: Installing the dependencies and setting up a GPU environment

# %%
# !pip install tensorflow-gpu==2.0.0

# %% [markdown]
# ## Step 2: Importing the libraries

# %%
import tensorflow as tf
from tensorflow.keras.datasets import imdb

# %%
tf.__version__
# Out:
# '2.0.0'

# %% [markdown]
# ## Step 3: Data Preprocessing

# %% [markdown]
# ### Setting up the dataset parameters

# %%
number_of_words = 20000
max_len = 100

# %% [markdown]
# ### Loading the IMDB dataset

# %%
import numpy as np

np.load.__defaults__=(None, True, True, 'ASCII')

# np_load_old = np.load
# np.load = lambda *a,**k: np_load_old(*a, allow_pickle=True, **k)
(X_train, y_train), (X_test, y_test) = imdb.load_data(num_words=number_of_words)
# np.load = np_load_old


np.load.__defaults__=(None, False, True, 'ASCII')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17465344/17464789 [==============================] - 0s 0us/step

# %% [markdown]
# ### Padding all sequences to be the same length

# %%
X_train = tf.keras.preprocessing.sequence.pad_sequences(X_train, maxlen=max_len)

# %%
X_test = tf.keras.preprocessing.sequence.pad_sequences(X_test, maxlen=max_len)

# %% [markdown]
# ## Step 4: Building a Recurrent Neural Network

# %% [markdown]
# ### Defining the model

# %%
model = tf.keras.Sequential()

# %% [markdown]
# ### Adding the embedding layer

# %%
model.add(tf.keras.layers.Embedding(input_dim=number_of_words, output_dim=128, input_shape=(X_train.shape[1],)))

# %% [markdown]
# ### Adding the LSTM layer
#
# - units: 128
# - activation: tanh

# %%
model.add(tf.keras.layers.LSTM(units=128, activation='tanh'))

# %% [markdown]
# ### Adding the output layer
#
# - units: 1
# - activation: sigmoid

# %%
model.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# %% [markdown]
# ### Compiling the model

# %%
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 100, 128)          2560000
# _________________________________________________________________
# lstm (LSTM)                  (None, 128)               131584
# _________________________________________________________________
# dense (Dense)                (None, 1)                 129
# =================================================================
# Total params: 2,691,713
# Trainable params: 2,691,713
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Training the model

# %%
model.fit(X_train, y_train, epochs=3, batch_size=128)
# Out:
# Train on 25000 samples
# Epoch 1/3
# 25000/25000 [==============================] - 12s 492us/sample - loss: 0.4762 - accuracy: 0.7765
# Epoch 2/3
# 25000/25000 [==============================] - 7s 274us/sample - loss: 0.2964 - accuracy: 0.8815
# Epoch 3/3
# 25000/25000 [==============================] - 7s 271us/sample - loss: 0.2319 - accuracy: 0.9104

# %% [markdown]
# ### Evaluating the model

# %%
test_loss, test_acurracy = model.evaluate(X_test, y_test)
# Out:
# 25000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %%
print("Test accuracy: {}".format(test_acurracy))
# Out:
# Test accuracy: 0.789359986782074
